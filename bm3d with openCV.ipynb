# %%
import bm3d
import cv2
from skimage import io, img_as_float
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from skimage.metrics import peak_signal_noise_ratio

# %%
img =img_as_float(io.imread("CNV-53018-1.jpeg", as_gray=True))

# %%
denoised= bm3d.bm3d(img, sigma_psd=30/255, stage_arg=bm3d.BM3DStages.HARD_THRESHOLDING)

# %%
io.imshow(denoised)


# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
io.imsave('filtered/abc.jpeg',denoised)

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(img.flat,bins=100,range=(0,1))

# %%
plt.hist(denoised.flat,bins=100,range=(0,1))

# %%
a=mean_squared_error(img, denoised)

# %%
a

# %%
anisotropic_cleaned_psnr = peak_signal_noise_ratio(img, denoised)

# %%
print(anisotropic_cleaned_psnr )

# %% [markdown]
# Filtering folders

# %%
import os
import cv2
import bm3d
import numpy as np
from skimage import io, img_as_float
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from skimage.metrics import peak_signal_noise_ratio
import glob

# %%
data_dir_path = u"test1/drusen/"
file_list = os.listdir(r'test1/drusen/')
data_dir_path2 = u"filtered1/fDrusen/"
a=0
for file_name in file_list:
    root, ext = os.path.splitext(file_name)
#         if ext == u'.png' or u'.jpeg' or u'.jpg':
    abs_name = data_dir_path +'/' + file_name
    img=img_as_float(io.imread(abs_name,as_gray=True))
    denoised= bm3d.bm3d(img, sigma_psd=30/255, stage_arg=bm3d.BM3DStages.HARD_THRESHOLDING)
    abs_name2 = data_dir_path2 +'/' + file_name
    # cv2.imwrite(str(a)+'., denoised)
    io.imsave(abs_name2,denoised)
    print(f"filtered by BM3D No:{a}")
    a+=1
# Out:
# o uint8 prior to saving to suppress this warning.
# filtered by BM3D No:884
# Lossy conversion from float64 to uint8. Range [0.012630651704967022, 1.0615841150283813]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:885
# Lossy conversion from float64 to uint8. Range [0.010574117302894592, 1.0600194931030273]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:886
# Lossy conversion from float64 to uint8. Range [0.02945290133357048, 1.039005160331726]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:887
# Lossy conversion from float64 to uint8. Range [0.02945290133357048, 1.039005160331726]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:888
# Lossy conversion from float64 to uint8. Range [0.03770751878619194, 1.0951778888702393]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:889
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:890
# Lossy conversion from float64 to uint8. Range [0.015574916265904903, 1.1327345371246338]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:891
# Lossy conversion from float64 to uint8. Range [0.015574916265904903, 1.1327345371246338]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:892
# Lossy conversion from float64 to uint8. Range [0.018252022564411163, 1.024932861328125]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:893
# Lossy conversion from float64 to uint8. Range [0.018252022564411163, 1.024932861328125]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:894
# Lossy conversion from float64 to uint8. Range [0.007531242910772562, 1.0388761758804321]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:895
# Lossy conversion from float64 to uint8. Range [0.007531242910772562, 1.0388761758804321]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:896
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:897
# Lossy conversion from float64 to uint8. Range [-0.009217183105647564, 0.9924418330192566]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:898
# Lossy conversion from float64 to uint8. Range [-0.009514277800917625, 0.9659309983253479]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:899
# Lossy conversion from float64 to uint8. Range [0.04124163091182709, 1.005997657775879]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:900
# Lossy conversion from float64 to uint8. Range [0.0480777733027935, 1.0247437953948975]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:901
# Lossy conversion from float64 to uint8. Range [0.047817081212997437, 1.1222809553146362]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:902
# Lossy conversion from float64 to uint8. Range [0.03795115649700165, 1.041858434677124]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:903
# Lossy conversion from float64 to uint8. Range [-0.015461057424545288, 1.0590842962265015]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:904
# Lossy conversion from float64 to uint8. Range [-0.004434945061802864, 1.098117709159851]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:905
# Lossy conversion from float64 to uint8. Range [-0.006310930009931326, 0.9827989935874939]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:906
# Lossy conversion from float64 to uint8. Range [-0.002379526849836111, 0.9591960310935974]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:907
# Lossy conversion from float64 to uint8. Range [0.02430180460214615, 1.0515657663345337]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:908
# Lossy conversion from float64 to uint8. Range [-0.004531353712081909, 0.9706481695175171]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:909
# Lossy conversion from float64 to uint8. Range [-0.007172532845288515, 0.9626190662384033]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:910
# Lossy conversion from float64 to uint8. Range [0.029069475829601288, 1.039677619934082]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:911
# Lossy conversion from float64 to uint8. Range [0.0291244275867939, 1.053337574005127]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:912
# Lossy conversion from float64 to uint8. Range [0.004117250442504883, 1.0258171558380127]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:913
# Lossy conversion from float64 to uint8. Range [0.03917582705616951, 1.2367796897888184]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:914
# Lossy conversion from float64 to uint8. Range [-0.007590414024889469, 1.052074909210205]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:915
# Lossy conversion from float64 to uint8. Range [-0.0028150032740086317, 1.0648587942123413]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:916
# Lossy conversion from float64 to uint8. Range [-0.010282792150974274, 0.9817010760307312]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:917
# Lossy conversion from float64 to uint8. Range [-0.01940750889480114, 0.9905427098274231]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:918
# Lossy conversion from float64 to uint8. Range [0.01318796630948782, 1.0635764598846436]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:919
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:920
# Lossy conversion from float64 to uint8. Range [0.0209796205163002, 1.0135619640350342]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:921
# Lossy conversion from float64 to uint8. Range [0.002508155070245266, 1.0267720222473145]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:922
# Lossy conversion from float64 to uint8. Range [0.04422766715288162, 1.028937816619873]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:923
# Lossy conversion from float64 to uint8. Range [0.03231469541788101, 1.0069572925567627]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:924
# Lossy conversion from float64 to uint8. Range [0.017070656642317772, 1.4278137683868408]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:925
# Lossy conversion from float64 to uint8. Range [0.017685191705822945, 1.1722633838653564]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:926
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:927
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:928
# Lossy conversion from float64 to uint8. Range [-0.021004261448979378, 1.1000351905822754]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:929
# Lossy conversion from float64 to uint8. Range [0.0006078049773350358, 1.0256339311599731]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:930
# Lossy conversion from float64 to uint8. Range [0.012873782776296139, 1.0388425588607788]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:931
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:932
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:933
# Lossy conversion from float64 to uint8. Range [-0.01493824739009142, 0.9904003739356995]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:934
# Lossy conversion from float64 to uint8. Range [-0.001199900871142745, 0.9050395488739014]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:935
# Lossy conversion from float64 to uint8. Range [-0.01905844360589981, 0.9545203447341919]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:936
# Lossy conversion from float64 to uint8. Range [0.029987147077918053, 1.1975919008255005]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:937
# Lossy conversion from float64 to uint8. Range [0.0011243873741477728, 1.386845350265503]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:938
# Lossy conversion from float64 to uint8. Range [0.019041866064071655, 1.7278112173080444]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:939
# Lossy conversion from float64 to uint8. Range [-0.0011524090077728033, 0.9495439529418945]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:940
# Lossy conversion from float64 to uint8. Range [0.0020685659255832434, 1.0773683786392212]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:941
# Lossy conversion from float64 to uint8. Range [0.012478730641305447, 1.0162700414657593]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:942
# Lossy conversion from float64 to uint8. Range [0.012212475761771202, 1.0230861902236938]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:943
# Lossy conversion from float64 to uint8. Range [-0.0034816160332411528, 0.9550320506095886]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:944
# Lossy conversion from float64 to uint8. Range [0.027757126837968826, 1.0000001192092896]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:945
# Lossy conversion from float64 to uint8. Range [0.025303125381469727, 1.0750494003295898]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:946
# Lossy conversion from float64 to uint8. Range [-0.03803108260035515, 1.1653910875320435]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:947
# Lossy conversion from float64 to uint8. Range [-0.00786706991493702, 1.0429744720458984]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:948
# Lossy conversion from float64 to uint8. Range [0.02745605818927288, 1.2025076150894165]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:949
# Lossy conversion from float64 to uint8. Range [0.009119641035795212, 1.120382308959961]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:950
# Lossy conversion from float64 to uint8. Range [0.0024319507647305727, 1.0559138059616089]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:951
# Lossy conversion from float64 to uint8. Range [0.011526212096214294, 1.052241325378418]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:952
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:953
# Lossy conversion from float64 to uint8. Range [0.03338661417365074, 1.0310190916061401]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:954
# Lossy conversion from float64 to uint8. Range [0.04289555549621582, 1.0352190732955933]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:955
# Lossy conversion from float64 to uint8. Range [0.050388455390930176, 1.0874569416046143]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:956
# Lossy conversion from float64 to uint8. Range [-0.017656322568655014, 1.039036750793457]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:957
# Lossy conversion from float64 to uint8. Range [0.028960665687918663, 1.0565718412399292]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:958
# Lossy conversion from float64 to uint8. Range [0.024130336940288544, 1.0815993547439575]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:959
# Lossy conversion from float64 to uint8. Range [0.024136947467923164, 1.0533331632614136]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:960
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:961
# Lossy conversion from float64 to uint8. Range [-0.00214512855745852, 1.1679834127426147]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:962
# Lossy conversion from float64 to uint8. Range [0.04036695137619972, 1.0660263299942017]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:963
# Lossy conversion from float64 to uint8. Range [-0.016625870019197464, 1.099810242652893]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:964
# Lossy conversion from float64 to uint8. Range [-0.00829530693590641, 1.0587657690048218]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:965
# Lossy conversion from float64 to uint8. Range [-0.0011896983487531543, 0.8320441246032715]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:966
# Lossy conversion from float64 to uint8. Range [-0.005696624517440796, 1.016627311706543]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:967
# Lossy conversion from float64 to uint8. Range [0.043358348309993744, 1.0288512706756592]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:968
# Lossy conversion from float64 to uint8. Range [0.04444437101483345, 1.1932257413864136]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:969
# Lossy conversion from float64 to uint8. Range [-0.0007998999208211899, 0.9388388991355896]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:970
# Lossy conversion from float64 to uint8. Range [0.01693759113550186, 1.163012146949768]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:971
# Lossy conversion from float64 to uint8. Range [0.0065032136626541615, 1.1834540367126465]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:972
# Lossy conversion from float64 to uint8. Range [0.02418982796370983, 1.0201736688613892]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:973
# Lossy conversion from float64 to uint8. Range [0.015403272584080696, 1.1013951301574707]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:974
# Lossy conversion from float64 to uint8. Range [-0.010541288182139397, 0.9428418874740601]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:975
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:976
# Lossy conversion from float64 to uint8. Range [0.02239575795829296, 1.0433319807052612]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:977
# Lossy conversion from float64 to uint8. Range [-0.0348607636988163, 1.4753836393356323]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:978
# Lossy conversion from float64 to uint8. Range [-0.021166114136576653, 1.1567455530166626]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:979
# Lossy conversion from float64 to uint8. Range [0.03354688361287117, 1.1492986679077148]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:980
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:981
# Lossy conversion from float64 to uint8. Range [0.031150473281741142, 1.0120398998260498]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:982
# Lossy conversion from float64 to uint8. Range [-0.01389249600470066, 0.9868534803390503]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:983
# Lossy conversion from float64 to uint8. Range [0.043401263654232025, 1.0301457643508911]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:984
# Lossy conversion from float64 to uint8. Range [0.061727602034807205, 1.0301973819732666]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:985
# Lossy conversion from float64 to uint8. Range [0.05433490499854088, 1.020802617073059]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:986
# Lossy conversion from float64 to uint8. Range [-0.015118102543056011, 1.0478136539459229]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:987
# Lossy conversion from float64 to uint8. Range [-0.0028855190612375736, 0.9568161368370056]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:988
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:989
# Lossy conversion from float64 to uint8. Range [-0.008898030035197735, 1.0065462589263916]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:990
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:991
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:992
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:993
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:994
# Lossy conversion from float64 to uint8. Range [0.018672673031687737, 1.1007740497589111]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:995
# Lossy conversion from float64 to uint8. Range [0.024219946935772896, 1.1168162822723389]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:996
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:997
# Lossy conversion from float64 to uint8. Range [-0.01676480658352375, 1.021573543548584]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:998
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# filtered by BM3D No:999
