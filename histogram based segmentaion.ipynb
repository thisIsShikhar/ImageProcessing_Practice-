# %%
from skimage.restoration import denoise_nl_means, estimate_sigma
from skimage import img_as_float, img_as_ubyte,io
import numpy as np
from matplotlib import pyplot as plt

# %%
img=img_as_float(io.imread("/home/shikhar/Desktop/git_workspace/ImageProcessing_Practice-/noisy_img.jpg"))

# %%
sigma_est=np.mean(estimate_sigma(img,multichannel=True))

# %%
denoise=denoise_nl_means(img, h=1.15*sigma_est, fast_mode=True,patch_size=5, patch_distance=3,multichannel=True)

# %%
plt.imshow(denoise, cmap="gray")

# %%
denoise_ubyte=img_as_ubyte(denoise)

# %%
plt.imshow(denoise_ubyte, cmap="gray")

# %%
plt.hist(denoise_ubyte.flat, bins=100, range=(0,80))
# Out:
# (array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         3.0000e+00, 6.0000e+00, 2.3000e+01, 5.2000e+01, 0.0000e+00,
#         2.7300e+02, 7.7800e+02, 1.9480e+03, 4.1170e+03, 0.0000e+00,
#         7.8450e+03, 1.2877e+04, 1.8129e+04, 2.2699e+04, 0.0000e+00,
#         2.5586e+04, 2.5824e+04, 2.4206e+04, 2.1568e+04, 0.0000e+00,
#         1.7605e+04, 1.4311e+04, 1.1652e+04, 9.6520e+03, 0.0000e+00,
#         7.9870e+03, 6.6500e+03, 5.9210e+03, 5.1330e+03, 0.0000e+00,
#         4.5870e+03, 4.4000e+03, 4.1360e+03, 3.8550e+03, 0.0000e+00,
#         3.7050e+03, 3.6900e+03, 3.5170e+03, 3.5640e+03, 0.0000e+00,
#         3.4110e+03, 3.1360e+03, 3.1260e+03, 2.9760e+03, 0.0000e+00,
#         2.8210e+03, 2.7030e+03, 2.4860e+03, 2.3750e+03, 0.0000e+00,
#         2.2130e+03, 2.1140e+03, 1.9660e+03, 1.8220e+03, 0.0000e+00,
#         1.7950e+03, 1.6850e+03, 1.5970e+03, 1.4320e+03, 0.0000e+00,
#         1.4100e+03, 1.3180e+03, 1.3770e+03, 1.2420e+03, 0.0000e+00,
#         1.2140e+03, 1.1730e+03, 1.1310e+03, 1.0930e+03, 0.0000e+00,
#         1.0680e+03, 1.0890e+03, 9.7900e+02, 9.5200e+02, 0.0000e+00,
#         9.2700e+02, 8.8100e+02, 8.8800e+02, 8.4800e+02, 0.0000e+00,
#         8.5400e+02, 8.5500e+02, 8.2000e+02, 8.4000e+02, 0.0000e+00,
#         8.3400e+02, 8.7600e+02, 9.3600e+02, 9.0000e+02, 9.5400e+02]),
#  array([ 0. ,  0.8,  1.6,  2.4,  3.2,  4. ,  4.8,  5.6,  6.4,  7.2,  8. ,
#          8.8,  9.6, 10.4, 11.2, 12. , 12.8, 13.6, 14.4, 15.2, 16. , 16.8,
#         17.6, 18.4, 19.2, 20. , 20.8, 21.6, 22.4, 23.2, 24. , 24.8, 25.6,
#         26.4, 27.2, 28. , 28.8, 29.6, 30.4, 31.2, 32. , 32.8, 33.6, 34.4,
#         35.2, 36. , 36.8, 37.6, 38.4, 39.2, 40. , 40.8, 41.6, 42.4, 43.2,
#         44. , 44.8, 45.6, 46.4, 47.2, 48. , 48.8, 49.6, 50.4, 51.2, 52. ,
#         52.8, 53.6, 54.4, 55.2, 56. , 56.8, 57.6, 58.4, 59.2, 60. , 60.8,
#         61.6, 62.4, 63.2, 64. , 64.8, 65.6, 66.4, 67.2, 68. , 68.8, 69.6,
#         70.4, 71.2, 72. , 72.8, 73.6, 74.4, 75.2, 76. , 76.8, 77.6, 78.4,
#         79.2, 80. ]),
#  <a list of 100 Patch objects>)

# %%
seg1=(denoise_ubyte <=55)
seg2=(denoise_ubyte >55) & (denoise_ubyte <=110)
seg3=(denoise_ubyte >110) & (denoise_ubyte <=210)
seg4=(denoise_ubyte >210)

all_segments=np.zeros((denoise_ubyte.shape[0],denoise_ubyte.shape[1],3))

all_segments[seg1]=250
all_segments[seg2]=110
all_segments[seg3]=210
all_segments[seg4]=000

# %%
plt.imshow(all_segments)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
