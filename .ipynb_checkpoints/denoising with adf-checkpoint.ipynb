# %%
import numpy as np 
from skimage import io, img_as_ubyte
from matplotlib import pyplot as plt
from medpy.filter.smoothing import anisotropic_diffusion

# %%
img =io.imread("/home/shikhar/Desktop/git_workspace/ImageProcessing_Practice-/noisy_img.jpg", as_gray=True)
# img =np.random.uniform(size=(32,32))

# %%
img_filtered=anisotropic_diffusion(img)

# %%
plt.imshow(img_filtered)

# %%
plt.imshow(img)

# %%
plt.imsave("/home/shikhar/Desktop/git_workspace/ImageProcessing_Practice-/denoising/adf.jpg", img)
