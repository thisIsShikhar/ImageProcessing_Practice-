# %%
from skimage import io, img_as_ubyte
from scipy import ndimage
import numpy as np
from matplotlib import pyplot as plt

# %%
img = img_as_ubyte(io.imread("/home/shikhar/Desktop/git_workspace/ImageProcessing_Practice-/Lenna-image-300300-a-Noisy-image-corrupted-by-Gaussian-noise-for-s35-b-Original.png", as_gray=True))

# %%
median_filtered=ndimage.median_filter(img,15)  #used for denoising images
plt.imshow(median_filtered)

# %%
plt.imshow(img)
