# %%
from skimage import io, img_as_ubyte
from scipy import ndimage
import numpy as np
from matplotlib import pyplot as plt

import bm3d

# %%
img =io.imread("/home/shikhar/Desktop/git_workspace/ImageProcessing_Practice-/noisy_img.jpg", as_gray=True)

# %%
denoised= bm3d.bm3d(img+0.5, sigma_psd=30/255, stage_arg=bm3d.BM3DStages.HARD_THRESHOLDING)

# %%
plt.imshow(denoised)
plt.imsave("/home/shikhar/Desktop/git_workspace/ImageProcessing_Practice-/denoising/bm3d.jpg", denoised)

# %%
plt.imshow(img)
plt.imsave("/home/shikhar/Desktop/git_workspace/ImageProcessing_Practice-/denoising/noised image.jpg", img)
